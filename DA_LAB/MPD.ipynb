# %% [markdown]
# # Mobile Phone Price Dataset

# %%
import pandas as pd

data = pd.read_csv("Mobile_phone_price.csv")

display(data)
# Out:
#        Brand              Model Storage    RAM  Screen Size (inches)  \
# 0      Apple      iPhone 13 Pro   128 GB   6 GB                  6.1
# 1    Samsung   Galaxy S21 Ultra   256 GB  12 GB                  6.8
# 2    OnePlus              9 Pro   128 GB   8 GB                  6.7
# 3     Xiaomi  Redmi Note 10 Pro   128 GB   6 GB                 6.67
# 4     Google            Pixel 6   128 GB   8 GB                  6.4
# ..       ...                ...      ...    ...                  ...
# 402  Samsung   Galaxy Note20 5G      128      8                  6.7
# 403   Xiaomi      Mi 10 Lite 5G      128      6                 6.57
# 404    Apple  iPhone 12 Pro Max      128      6                  6.7
# 405     Oppo              Reno3      128      8                  6.4
# 406  Samsung    Galaxy S10 Lite      128      6                  6.7
#
#             Camera (MP)  Battery Capacity (mAh) Price ($)
# 0          12 + 12 + 12                    3095       999
# ...

# %% [markdown]
# ### a. Identify the models & the price released by each brand.

# %%
for key, value in data.groupby("Brand")[["Model","Price ($)"]]:
    print(key)
    display(value)
# Out:
# Apple
#                    Model Price ($)
# 0          iPhone 13 Pro       999
# 5              iPhone 13       799
# 13        iPhone 12 Mini       699
# 25             iPhone 11       599
# 32   iPhone SE (2nd Gen)       399
# 39             iPhone XR       499
# 45        iPhone 12 Mini       699
# 51     iPhone 11 Pro Max      1099
# 57     iPhone 13 Pro Max      1299
# 62      iPhone SE (2020)       399
# 68             iPhone XR       499
# 74             iPhone 11       599
# 77             iPhone 13     $799
# 289     iPhone SE (2020)       399
# 297    iPhone 11 Pro Max      1099
# 305            iPhone 13       799
# 308            iPhone XR       599
# 318            iPhone 12       799
# 326            iPhone 11       699
# 333     iPhone SE (2020)       399
# 338        iPhone XS Max      1099
# 347        iPhone 8 Plus       699
# 355            iPhone XR       499
# 362    iPhone 11 Pro Max      1099
# 369       iPhone 12 mini       899
# ...

# %% [markdown]
# ### b. Identify the correlation between Battery Capacity and price.

# %%
data['Price'] = [int("".join(filter(str.isdigit, s))) for s in data['Price ($)']]

correlation = data['Battery Capacity (mAh)'].corr(data['Price'])

print(f"Correlation between Battery Capacity and Price: {correlation}")
# Out:
# Correlation between Battery Capacity and Price: -0.39658137643652014

# %% [markdown]
# ### c. Find how many models are there per each Battery capacity with same price.

# %%
display(data.groupby(['Battery Capacity (mAh)', 'Price'])['Model'].count().reset_index())
# Out:
#      Battery Capacity (mAh)  Price  Model
# 0                      1821    399      4
# 1                      1821    449      1
# 2                      2227    699      2
# 3                      2227    899      1
# 4                      2691    699      1
# ..                      ...    ...    ...
# 174                    6000    349      1
# 175                    6000    379      1
# 176                    6000    999      1
# 177                    7000    429      1
# 178                    7000    449      1
#
# [179 rows x 3 columns]

# %% [markdown]
# ### d. Count the number of models in each brand with highest storage. Draw the graph.

# %%
import matplotlib.pyplot as plt

data["Storage"] = [int("".join(filter(str.isdigit, s))) for s in data["Storage "]]

max_storage = data.groupby('Brand')['Storage'].max()
models = data[data.groupby('Brand')['Storage'].transform(max) == data['Storage']]
models_count = models.groupby('Brand')['Model'].count()

plt.figure(figsize=(10, 6))
plt.bar(models_count.index, models_count, width=0.6, color='skyblue')

plt.xlabel('Brand')
plt.ylabel('Number of Models with Highest Storage')
plt.title('Number of Models with Highest Storage in Each Brand')

plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# ### e. Identify how many models are released by each brand.

# %%
print(data.groupby("Brand")['Model'].nunique())
# Out:
# Brand
# Apple         15
# Asus           3
# Blackberry     3
# CAT            1
# Google         4
# Huawei        10
# LG             3
# Motorola      19
# Nokia         17
# OnePlus       10
# Oppo          33
# Realme        24
# Samsung       42
# Sony           1
# Vivo          21
# Xiaomi        33
# Name: Model, dtype: int64

# %% [markdown]
# ### f. Find the RAM capacity of all models of every brand.

# %%
data["RAM"] = [int("".join(filter(str.isdigit, s))) for s in data["RAM "]]

for i,j in data.groupby('Brand')[['Model','RAM']]:
    print('-'*50)
    print(i)
    print('-'*50)
    print(j.drop_duplicates())
    print("\n")
# Out:
# --------------------------------------------------
# Apple
# --------------------------------------------------
#                    Model  RAM
# 0          iPhone 13 Pro    6
# 5              iPhone 13    4
# 13        iPhone 12 Mini    4
# 25             iPhone 11    4
# 32   iPhone SE (2nd Gen)    3
# 39             iPhone XR    3
# 51     iPhone 11 Pro Max    4
# 57     iPhone 13 Pro Max    6
# 62      iPhone SE (2020)    3
# 305            iPhone 13    6
# 318            iPhone 12    4
# 338        iPhone XS Max    4
# 347        iPhone 8 Plus    3
# 369       iPhone 12 mini    4
# 384        iPhone 12 Pro    6
# 404    iPhone 12 Pro Max    6
#
#
# --------------------------------------------------
# Asus
# --------------------------------------------------
#               Model  RAM
# 89   Zenfone 8 Flip    8
# 99        Zenfone 8    6
# 112     ROG Phone 5    8
#
#
# --------------------------------------------------
# Blackberry
# ...

# %% [markdown]
# ### g.  Find how many models are there per each Battery capacity.

# %%
display(data.groupby('Battery Capacity (mAh)')['Model'].count().reset_index())
# Out:
#     Battery Capacity (mAh)  Model
# 0                     1821      5
# 1                     2227      3
# 2                     2691      1
# 3                     2800      1
# 4                     2815      5
# 5                     2942      5
# 6                     3000      1
# 7                     3095      1
# 8                     3110      4
# 9                     3174      1
# 10                    3300      2
# 11                    3340      1
# 12                    3500      4
# 13                    3687      1
# 14                    3885      1
# 15                    3969      3
# 16                    4000     34
# 17                    4025      1
# 18                    4080      3
# 19                    4100      1
# 20                    4115      1
# 21                    4160      1
# 22                    4200      8
# 23                    4230      6
# 24                    4250      6
# 25                    4300      7
# ...

# %% [markdown]
# ### h. Calculate average price of each brand.

# %%
print(data.groupby('Brand')['Price'].mean())
# Out:
# Brand
# Apple          745.666667
# Asus           874.000000
# Blackberry     499.000000
# CAT            299.000000
# Google         699.000000
# Huawei         783.166667
# LG             615.666667
# Motorola       278.130435
# Nokia          244.714286
# OnePlus        644.333333
# Oppo           376.142857
# Realme         206.906977
# Samsung        480.405063
# Sony          1299.000000
# Vivo           323.000000
# Xiaomi         282.880597
# Name: Price, dtype: float64

# %% [markdown]
# ### i. Find which mobile brand has highest price.

# %%
max_brand = data.groupby('Brand')['Price'].max()

brand = max_brand.idxmax()
max_price = max_brand.max()

print(f"The brand with the highest price is {brand} with a price of ${max_price:.2f}")

data[data['Price'] == max(data['Price'])][["Brand","Model","Price"]]
# Out:
# The brand with the highest price is Samsung with a price of $1999.00
#        Brand              Model  Price
# 373  Samsung  Galaxy Z Fold2 5G   1999

# %% [markdown]
# ### j. Identify any missing values are there in mobile phone price dataset.

# %%
print("Missing values in the dataset = ",data.isnull().sum().sum())
# Out:
# Missing values in the dataset =  0

# %% [markdown]
# ### k. Display all models associated with apple brand.

# %%
print("Models of Apple Brand:")
print(data[data["Brand"] == "Apple"]["Model"].unique())
# Out:
# Models of Apple Brand:
# ['iPhone 13 Pro' 'iPhone 13' 'iPhone 12 Mini' 'iPhone 11'
#  'iPhone SE (2nd Gen)' 'iPhone XR' 'iPhone 11 Pro Max' 'iPhone 13 Pro Max'
#  'iPhone SE (2020)' 'iPhone 12' 'iPhone XS Max' 'iPhone 8 Plus'
#  'iPhone 12 mini' 'iPhone 12 Pro' 'iPhone 12 Pro Max']

# %% [markdown]
# ### l. Find the mobile prices based on Camera (MP).

# %%
data.groupby('Camera (MP)')[['Camera (MP)', 'Price ($)']].head()
# Out:
#             Camera (MP) Price ($)
# 0          12 + 12 + 12       999
# 1    108 + 10 + 10 + 12      1199
# 2       48 + 50 + 8 + 2       899
# 3        64 + 8 + 5 + 2       279
# 4             50 + 12.2       799
# ..                  ...       ...
# 400             48+16+2       329
# 401              48+8+2       329
# 402            12+64+12      1049
# 405           48+13+8+2       429
# 406             48+12+5       649
#
# [316 rows x 2 columns]

# %% [markdown]
# ### m. List the models along with brands which have highest storage.

# %%
max_storage = data["Storage"].max()

display(data[data['Storage'] == max_storage][["Brand", "Model", "Storage"]])
# Out:
#        Brand                Model  Storage
# 297    Apple    iPhone 11 Pro Max      512
# 361   Huawei             P40 Pro+      512
# 367  Samsung  Galaxy S20 Ultra 5G      512

# %% [markdown]
# ### n. How many models in each brand having RAM>6.

# %%
display(data.query('RAM > 6').groupby("Brand")["Model"].count())

#display(data[data["RAM"] > 6].groupby("Brand")["Model"].count())
# Out:
# Brand
# Asus         3
# Google       5
# Huawei      10
# LG           1
# Motorola     1
# Nokia        2
# OnePlus     12
# Oppo        25
# Realme      11
# Samsung     19
# Sony         1
# Vivo        21
# Xiaomi      10
# Name: Model, dtype: int64

# %% [markdown]
# ### o. List the models having price > 600 and Storage between 100 and 200.

# %%
display(data.query("Price > 600 & Storage >= 100 & Storage <= 200")[["Brand","Model", "Price", "Storage"]])

#display(data[(data["Price"] > 600) & (data["Storage"] >= 100) & (data["Storage"] <= 200)][["Brand","Model", "Price", "Storage"]])
# Out:
#        Brand                Model  Price  Storage
# 0      Apple        iPhone 13 Pro    999      128
# 2    OnePlus                9 Pro    899      128
# 4     Google              Pixel 6    799      128
# 5      Apple            iPhone 13    799      128
# 8       Oppo        Reno6 Pro+ 5G    699      128
# 16   Samsung           Galaxy S21    799      128
# 23   OnePlus                    9    729      128
# 60      Oppo         Reno6 Pro 5G    659      128
# 77     Apple            iPhone 13    799      128
# 78   Samsung           Galaxy S21    799      128
# 80    Google              Pixel 6    699      128
# 87      Sony         Xperia 5 III   1299      128
# 99      Asus            Zenfone 8    699      128
# 102  Samsung      Galaxy Z Flip 3    999      128
# 108  Samsung     Galaxy S20 FE 5G    699      128
# 112     Asus          ROG Phone 5    999      128
# 123     Asus       Zenfone 8 Flip    899      128
# 291   Google              Pixel 5    699      128
# ...
