# %% [markdown]
# # National Universities Rankings.

# %%
import pandas as pd

data = pd.read_csv("National_Universities_Rankings.csv")

display(data)
# Out:
#      index                                      Name             Location  \
# 0        0                      Princeton University        Princeton, NJ
# 1        1                        Harvard University        Cambridge, MA
# 2        2                     University of Chicago          Chicago, IL
# 3        3                           Yale University        New Haven, CT
# 4        4                       Columbia University         New York, NY
# ..     ...                                       ...                  ...
# 226    226    University of Massachusetts--Dartmouth  North Dartmouth, MA
# 227    227         University of Missouri--St. Louis        St. Louis, MO
# 228    228  University of North Carolina--Greensboro       Greensboro, NC
# 229    229        University of Southern Mississippi      Hattiesburg, MS
# 230    230                     Utah State University            Logan, UT
#
#      Rank                                        Description Tuition and fees  \
# 0       1  Princeton, the fourth-oldest college in the Un...         $45,320
# 1       2  Harvard is located in Cambridge, Massachusetts...         $47,074
# 2       3  The University of Chicago, situated in Chicago...         $52,491
# 3       3  Yale University, located in New Haven, Connect...         $49,480
# 4       5  Columbia University, located in Manhattan's Mo...         $55,056
# ..    ...                                                ...              ...
# 226   220  Located about 60 miles south of Boston, the Un...         $19,270
# 227   220  Undergraduates at University of Missouri--St. ...         $26,277
# 228   220  University of North Carolina--Greensboro is lo...         $21,595
# 229   220  The University of Southern Mississippi has two...         $16,094
# 230   220  Founded in 1888, Utah State University is a pu...         $19,772
#
#      In-state Undergrad Enrollment
# 0         NaN                5,402
# 1         NaN                6,699
# 2         NaN                5,844
# 3         NaN                5,532
# 4         NaN                6,102
# ..        ...                  ...
# 226  $12,588                 7,295
# 227  $10,065                13,569
# 228   $6,733                15,951
# 229   $7,224                11,840
# 230   $6,866                25,259
#
# [231 rows x 8 columns]

# %% [markdown]
# ### a. Find the universities along with state whose fee is in between 25,000 to 30,000.

# %%
data["TuitionFees"] = [int("".join(filter(str.isdigit, s))) for s in data["Tuition and fees"]]

df = data[(data["TuitionFees"] >= 25000) & (data["TuitionFees"] <= 30000)]

display(df[['Name', 'Location', 'Rank', 'Tuition and fees']])
# Out:
#                                                   Name             Location  \
# 50                               University of Florida      Gainesville, FL
# 53                     Ohio State University--Columbus         Columbus, OH
# 57                               University of Georgia           Athens, GA
# 60                   Purdue University--West Lafayette   West Lafayette, IN
# 68                            University of Pittsburgh       Pittsburgh, PA
# 75               Texas A&M University--College Station  College Station, TX
# 77                                       Virginia Tech       Blacksburg, VA
# 84                                  University of Iowa        Iowa City, IA
# 92            North Carolina State University--Raleigh          Raleigh, NC
# 97                        Stony Brook University--SUNY      Stony Brook, NY
# 98                                   Auburn University           Auburn, AL
# 101                        University at Buffalo--SUNY          Buffalo, NY
# 103                              University of Alabama       Tuscaloosa, AL
# 112                             University of Missouri         Columbia, MO
# 116                                 University of Utah   Salt Lake City, UT
# 119                                  Temple University     Philadelphia, PA
# 121                               University of Kansas         Lawrence, KS
# 128                    Arizona State University--Tempe            Tempe, AZ
# 130                          Colorado State University     Fort Collins, CO
# 133                             University of Kentucky        Lexington, KY
# 135            Louisiana State University--Baton Rouge      Baton Rouge, LA
# 138                         Rutgers University--Newark           Newark, NJ
# 140                           University of Cincinnati       Cincinnati, OH
# 143                            Oregon State University        Corvallis, OR
# 144                        Washington State University          Pullman, WA
# 155                    University of Illinois--Chicago          Chicago, IL
# 157                University of Massachusetts--Lowell           Lowell, MA
# 161                         University of Rhode Island         Kingston, RI
# 164                  Maryville University of St. Louis         St Louis, MO
# 165        Missouri University of Science & Technology            Rolla, MO
# 170                                   Edgewood College          Madison, WI
# 175                              Ball State University           Muncie, IN
# 176                                Lipscomb University        Nashville, TN
# 182                                 Andrews University  Berrien Springs, MI
# 184                                University of Maine            Orono, ME
# 190                           Robert Morris University    Moon Township, PA
# 194                              University of Houston          Houston, TX
# 195                        Western Michigan University        Kalamazoo, MI
# 196  Indiana University-Purdue University--Indianap...     Indianapolis, IN
# 197                                  Lesley University        Cambridge, MA
# 199                     University of Colorado--Denver           Denver, CO
# 203                          Louisiana Tech University           Ruston, LA
# 211                            Old Dominion University          Norfolk, VA
# 214                          Dallas Baptist University           Dallas, TX
# 216                       Nova Southeastern University   Ft. Lauderdale, FL
# 217           Southern Illinois University--Carbondale       Carbondale, IL
# 221                            Gardner-Webb University  Boiling Springs, NC
# 227                  University of Missouri--St. Louis        St. Louis, MO
#
#      Rank Tuition and fees
# 50     50         $28,666
# 53     54         $29,229
# 57     56         $29,844
# 60     60         $28,804
# 68     68         $29,758
# 75     74         $28,768
# 77     74         $29,371
# 84     82         $28,413
# 92     92         $26,399
# 97     96         $26,266
# 98     99         $28,840
# 101    99         $26,270
# 103   103         $26,950
# 112   111         $25,892
# 116   111         $27,039
# 119   118         $25,994
# 121   118         $25,932
# 128   129         $25,458
# 130   129         $28,374
# 133   133         $26,334
# 135   135         $27,005
# 138   135         $29,480
# 140   135         $26,334
# 143   143         $28,846
# 144   143         $25,673
# 155   152         $26,526
# 157   152         $29,125
# 161   159         $28,852
# 164   164         $27,958
# 165   164         $26,152
# 170   171         $27,530
# 175   176         $25,428
# 176   176         $29,756
# 182   183         $27,684
# 184   183         $29,498
# 190   188         $28,250
# 194   194         $25,410
# 195   194         $25,713
# 196   197         $29,791
# 197   197         $25,750
# 199   197         $29,334
# 203   202         $25,851
# 211   210         $27,028
# 214   214         $26,180
# 216   214         $27,660
# 217   214         $27,130
# 221   220         $29,850
# 227   220         $26,277

# %% [markdown]
# ### b. Find university where undergraduate enrollement is more than 25000 containing in-state students.

# %%
data["UndergradEnrollment"] = [int("".join(filter(str.isdigit, s))) for s in data["Undergrad Enrollment"]]

df = data[data['UndergradEnrollment'] > 25000]

display(df[['Name', 'Location', 'Rank', 'In-state', 'Undergrad Enrollment']])
# Out:
#                                                Name             Location  \
# 21               University of California--Berkeley         Berkeley, CA
# 24            University of California--Los Angeles      Los Angeles, CA
# 27                University of Michigan--Ann Arbor        Ann Arbor, MI
# 35                              New York University         New York, NY
# 42                 University of California--Irvine           Irvine, CA
# 44                  University of California--Davis            Davis, CA
# 45              University of California--San Diego         La Jolla, CA
# 46         University of Illinois--Urbana-Champaign        Champaign, IL
# 48                 University of Wisconsin--Madison          Madison, WI
# 50                            University of Florida      Gainesville, FL
# 52   Pennsylvania State University--University Park  University Park, PA
# 53                  Ohio State University--Columbus         Columbus, OH
# 54                         University of Washington          Seattle, WA
# 57                            University of Georgia           Athens, GA
# 58                      University of Texas--Austin           Austin, TX
# 60                Purdue University--West Lafayette   West Lafayette, IN
# 63             University of Maryland--College Park     College Park, MD
# 67                  Brigham Young University--Provo            Provo, UT
# 69                Rutgers University--New Brunswick       Piscataway, NJ
# 72             University of Minnesota--Twin Cities      Minneapolis, MN
# 75            Texas A&M University--College Station  College Station, TX
# 77                                    Virginia Tech       Blacksburg, VA
# 82                        Michigan State University     East Lansing, MI
# 86                  Indiana University--Bloomington      Bloomington, IN
# 91                         Florida State University      Tallahassee, FL
# 93                  University of Colorado--Boulder          Boulder, CO
# 103                           University of Alabama       Tuscaloosa, AL
# 109                    University of South Carolina         Columbia, SC
# 110                           Iowa State University             Ames, IA
# 112                          University of Missouri         Columbia, MO
# 119                               Temple University     Philadelphia, PA
# 127                           University of Arizona           Tucson, AZ
# 128                 Arizona State University--Tempe            Tempe, AZ
# 135         Louisiana State University--Baton Rouge      Baton Rouge, LA
# 140                        University of Cincinnati       Cincinnati, OH
# 147                      San Diego State University        San Diego, CA
# 162                     University of South Florida            Tampa, FL
# 179                           Texas Tech University          Lubbock, TX
# 180                   University of Central Florida          Orlando, FL
# 194                           University of Houston          Houston, TX
# 201          California State University--Fullerton        Fullerton, CA
# 230                           Utah State University            Logan, UT
#
#      Rank  In-state Undergrad Enrollment
# 21     20  $13,509                27,496
# 24     24  $12,836                29,585
# 27     27  $13,856                28,312
# 35     36       NaN               25,722
# 42     39  $14,750                25,256
# 44     44  $14,046                28,384
# 45     44  $14,705                26,590
# 46     44  $15,698                33,368
# 48     44  $10,488                31,662
# 50     50   $6,389                35,043
# 52     50  $17,900                40,742
# 53     54  $10,037                45,289
# 54     54  $10,753                31,063
# 57     56  $11,634                27,547
# 58     56   $9,806                39,619
# 60     60  $10,002                29,497
# 63     60  $10,181                27,443
# 67     68       NaN               30,221
# 69     70  $14,372                35,484
# 72     71  $13,790                34,071
# 75     74  $10,176                48,960
# 77     74  $12,852                25,384
# 82     82  $14,070                39,143
# 86     86  $10,388                38,364
# 91     92   $9,507                32,706
# 93     92  $11,531                27,010
# 103   103  $10,470                31,958
# 109   107  $11,854                25,237
# 110   111   $7,969                30,034
# 112   111   $9,518                27,812
# 119   118  $15,688                28,609
# 127   124  $10,872                33,732
# 128   129  $10,158                41,828
# 135   135   $9,842                26,156
# 140   135  $11,000                25,054
# 147   146   $7,084                29,234
# 162   159   $6,410                31,111
# 179   176  $10,622                29,237
# 180   176   $6,368                54,513
# 194   194  $10,710                34,716
# 201   202   $6,436                33,144
# 230   220   $6,866                25,259

# %% [markdown]
# ### c. Find the states where universities are located in three or more cities.

# %%
data["state"] = [i[-2:] for i in data['Location']]

city_counts = data.groupby("state")["Name"].count()

display(city_counts[city_counts >= 3].reset_index())
# Out:
#    state  Name
# 0     AL     4
# 1     CA    22
# 2     CO     5
# 3     CT     3
# 4     DC     5
# 5     FL     7
# 6     GA     4
# 7     IL    11
# 8     IN     5
# 9     LA     3
# 10    MA    15
# 11    MD     3
# 12    MI     6
# 13    MO     7
# 14    MS     3
# 15    NC     8
# 16    NJ     7
# 17    NY    21
# 18    OH     9
# 19    OK     3
# 20    PA    12
# 21    TN     5
# 22    TX    10
# 23    UT     3
# 24    VA     7
# 25    WA     3
# 26    WI     3

# %% [markdown]
# ### d. Find max and min tuition fee in each state.

# %%
display(data.groupby('state').agg({'Tuition and fees': ['max', 'min']}))
# Out:
#       Tuition and fees
#                    max       min
# state
# AK            $22,469   $22,469
# AL            $28,840   $17,654
# AR            $23,168   $23,168
# AZ            $30,025   $25,458
# CA            $52,217   $17,209
# CO            $46,362   $28,374
# CT            $49,480   $35,858
# DC            $51,950   $24,908
# DE            $31,420   $31,420
# FL            $47,004   $17,325
# GA            $47,954   $29,844
# HI            $33,764   $33,764
# IA            $28,413   $21,483
# ID            $22,040   $22,040
# IL            $52,491   $20,886
# IN            $49,685   $25,428
# KS            $25,932   $23,429
# KY            $26,334   $24,626
# LA            $51,010   $25,851
# MA            $52,430   $19,270
# MD            $50,410   $24,492
# ME            $29,498   $29,498
# MI            $43,476   $23,670
# MN            $39,594   $22,210
# MO            $49,770   $22,714
# MS            $22,012   $16,094
# MT            $24,562   $23,042
# NC            $51,265   $20,193
# ND            $19,790   $18,899
# NE            $23,148   $23,148
# NH            $51,438   $31,424
# NJ            $48,838   $20,318
# NM            $21,302   $21,234
# NV            $21,052   $21,052
# NY            $55,056   $17,620
# OH            $46,006   $18,332
# OK            $38,796   $20,978
# OR            $33,442   $28,846
# PA            $52,040   $25,994
# RI            $51,367   $28,852
# SC            $32,796   $31,282
# SD            $11,688   $11,403
# TN            $45,610   $24,800
# TX            $50,358   $22,861
# UT             $5,300   $19,772
# VA            $45,066   $27,028
# VT            $40,364   $40,364
# WA            $38,940   $25,673
# WI            $38,470   $27,530
# WV            $21,432   $21,432
# WY            $16,215   $16,215

# %% [markdown]
# ### e. Find the city and state where maximum tuition fee difference in the universities in that city is greater than 5,000.

# %%
df = data.groupby('Location').agg({'TuitionFees': ['max', 'min']})

display(df[(df[("TuitionFees","max")] - df[("TuitionFees","min")]) > 5000])
# Out:
#                  TuitionFees
#                          max    min
# Location
# Atlanta, GA            47954  32404
# Baltimore, MD          50410  24492
# Boston, MA             50240  32023
# Cambridge, MA          48452  25750
# Chicago, IL            52491  26526
# Dallas, TX             50358  26180
# Denver, CO             46362  29334
# Houston, TX            43918  25410
# Los Angeles, CA        52217  39518
# Madison, WI            32738  27530
# Nashville, TN          45610  29756
# New York, NY           55056  40670
# Philadelphia, PA       51464  25994
# Pittsburgh, PA         52040  29758
# Rochester, NY          50142  31880
# San Diego, CA          46140  18244
# St. Louis, MO          49770  26277
# Syracuse, NY           45022  17620
# Washington, DC         51950  24908

# %% [markdown]
# ### f. Identify the correlation between Enrollment Number and University Rank.

# %%
print("The correlation between Enrollment Number and University Rank is:",data["UndergradEnrollment"].corr(data["Rank"]))
# Out:
# The correlation between Enrollment Number and University Rank is: -0.04077093578774782

# %% [markdown]
# ### g. Print university name and where it is located.

# %%
display(data[["Name","Location"]])
# Out:
#                                          Name             Location
# 0                        Princeton University        Princeton, NJ
# 1                          Harvard University        Cambridge, MA
# 2                       University of Chicago          Chicago, IL
# 3                             Yale University        New Haven, CT
# 4                         Columbia University         New York, NY
# ..                                        ...                  ...
# 226    University of Massachusetts--Dartmouth  North Dartmouth, MA
# 227         University of Missouri--St. Louis        St. Louis, MO
# 228  University of North Carolina--Greensboro       Greensboro, NC
# 229        University of Southern Mississippi      Hattiesburg, MS
# 230                     Utah State University            Logan, UT
#
# [231 rows x 2 columns]

# %% [markdown]
# ### h. Find cities having more than two universities along with state.

# %%
city_counts = data.groupby("Location")["Name"].count()

display(city_counts[city_counts > 2].reset_index())
# Out:
#            Location  Name
# 0        Boston, MA     4
# 1     Cambridge, MA     3
# 2       Chicago, IL     5
# 3      New York, NY     6
# 4  Philadelphia, PA     3
# 5    Pittsburgh, PA     3
# 6     Rochester, NY     3
# 7     St. Louis, MO     3
# 8    Washington, DC     5

# %% [markdown]
# ### i. Find the number of states and cities locating top 100 universities.

# %%
print(f"Number of states locating top 100 universities: {data.head(100)['state'].nunique()}")
print(f"Number of cities locating top 100 universities: {data.head(100)['Location'].nunique()}")
# Out:
# Number of states locating top 100 universities: 33
# Number of cities locating top 100 universities: 86

# %% [markdown]
# ### j. Draw the plot to show undergraduate enrollment of each university.

# %%
import matplotlib.pyplot as plt

plt.bar(data.head(5)['Name'], data.head(5)['UndergradEnrollment'])

plt.xlabel('University')
plt.ylabel('Undergraduate Enrollment')
plt.title('Undergraduate Enrollment of Each University')

plt.xticks(rotation=30, ha="center")
plt.show()

# %% [markdown]
# ### k. Draw the plot to show university name and its corresponding tuition fee.

# %%
import matplotlib.pyplot as plt

plt.bar(data.head(5)['Name'], data.head(5)['TuitionFees'])

plt.xlabel('University')
plt.ylabel('Tuition Fees')
plt.title('Tuition Fees of Each University')

plt.xticks(rotation=30, ha="center")
plt.show()

# %% [markdown]
# ### l. Plot the number of universities in each state having ranks > 100.

# %%
import matplotlib.pyplot as plt

filtered_data = data[data['Rank'] > 100]

state_counts = filtered_data.groupby('state').size()

plt.figure(figsize=(15, 6))
state_counts.plot(kind='bar')

plt.xlabel('State')
plt.ylabel('Number of Universities (Rank > 100)')
plt.title('Number of Universities in Each State')

plt.xticks(rotation=0, ha='center')
plt.show()
